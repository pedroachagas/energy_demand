# %% [markdown]
# # Data Quality Checks Generation

# %% [markdown]
# # Setup

# %% [markdown]
# ## Imports

# %%
import sys
sys.path.append('../')

from src.config.config import config
from src.utils.azure_utils import get_azure_blob_fs
from src.utils.logging_utils import logger

import pandas as pd
import numpy as np
import pyarrow.dataset as ds
import json

from tdda.constraints import discover_df

# %% [markdown]
# ## Functions

# %%
def load_gold_data() -> pd.DataFrame:
    """
    Load the latest Gold layer data from Azure Blob Storage into a Pandas DataFrame.

    Returns:
        pd.DataFrame: The Gold layer data with columns renamed and sorted by date.
    """
    gold_blob_path = f"{config.CONTAINER_NAME}/{config.FOLDER}/gold/"

    # Find the latest file
    logger.info(f"Finding the latest file in {gold_blob_path}")
    abfs = get_azure_blob_fs()
    files = abfs.ls(gold_blob_path)
    latest_file = max(files, key=lambda x: x.split("/")[-1])
    gold_blob_path = latest_file

    # Load the Gold Parquet file
    logger.info(f"Loading Gold data from {gold_blob_path}")
    pqdata = ds.dataset(gold_blob_path, filesystem=abfs)

    return (
        pqdata
        .to_table()
        .to_pandas()
        .reset_index(drop=True)
    )

def load_silver_data():
    """
    Load the latest Silver layer data from Azure Blob Storage into a Pandas DataFrame.

    Returns:
        pd.DataFrame: The Silver layer data with columns renamed and sorted by date.
    """
    silver_blob_path = f"{config.CONTAINER_NAME}/{config.FOLDER}/silver/"

    # Find the latest file
    logger.info(f"Finding the latest file in {silver_blob_path}")
    abfs = get_azure_blob_fs()
    files = abfs.ls(silver_blob_path)
    latest_file = max(files, key=lambda x: x.split("/")[-1])
    silver_blob_path = latest_file

    # Load the Silver Parquet file
    logger.info(f"Loading Silver data from {silver_blob_path}")
    pqdata = ds.dataset(silver_blob_path, filesystem=abfs)

    return (
        pqdata
        .to_table()
        .to_pandas()
        .reset_index(drop=True)
    )

def load_bronze_data() -> pd.DataFrame:
    """
    Load the latest Bronze layer data from Azure Blob Storage into a Pandas DataFrame.

    Returns:
        pd.DataFrame: The Bronze layer data with columns renamed and sorted by date.
    """
    bronze_blob_path = f"{config.CONTAINER_NAME}/{config.FOLDER}/bronze/"

    # Find the latest file
    logger.info(f"Finding the latest file in {bronze_blob_path}")
    abfs = get_azure_blob_fs()
    files = abfs.ls(bronze_blob_path)
    latest_file = max(files, key=lambda x: x.split("/")[-1])
    bronze_blob_path = latest_file

    # Load the Bronze JSON file
    logger.info(f"Loading Bronze data from {bronze_blob_path}")
    with abfs.open(bronze_blob_path, "r") as file:
        return pd.DataFrame(json.load(file))


def load_predictions() -> pd.DataFrame:
    """
    Load the latest predictions data from Azure Blob Storage into a Pandas DataFrame.

    Returns:
        pd.DataFrame: The predictions data sorted by date.
    """
    predictions_blob_path = f"{config.CONTAINER_NAME}/{config.FOLDER}/predictions/"

    # Find the latest file
    abfs = get_azure_blob_fs()
    files = abfs.ls(predictions_blob_path)
    latest_file = max(files, key=lambda x: x.split("/")[-1])
    predictions_blob_path = latest_file

    # Load the predictions Parquet file
    logger.info(f"Loading predictions from {predictions_blob_path}")
    pqdata = ds.dataset(predictions_blob_path, filesystem=abfs)

    return (
        pqdata
        .to_table()
        .to_pandas()
        .reset_index(drop=True)
    )

# %% [markdown]
# # Load Data

# %%
bronze = load_bronze_data()
silver = load_silver_data()
gold = load_gold_data()
predictions = load_predictions()
data_dict = {
    "bronze": bronze,
    "silver": silver,
    "gold": gold,
    "predictions": predictions
}
# Out:
# 2024-08-27 20:43:36.584 | INFO     | __main__:load_bronze_data:65 - Finding the latest file in data/energy_consumption/bronze/
# 2024-08-27 20:43:37.606 | INFO     | __main__:load_bronze_data:72 - Loading Bronze data from data/energy_consumption/bronze/raw_data_20240827.json
# 2024-08-27 20:43:45.976 | INFO     | __main__:load_silver_data:38 - Finding the latest file in data/energy_consumption/silver/
# 2024-08-27 20:43:46.378 | INFO     | __main__:load_silver_data:45 - Loading Silver data from data/energy_consumption/silver/cleaned_data_20240827.parquet
# 2024-08-27 20:43:47.458 | INFO     | __main__:load_gold_data:11 - Finding the latest file in data/energy_consumption/gold/
# 2024-08-27 20:43:48.052 | INFO     | __main__:load_gold_data:18 - Loading Gold data from data/energy_consumption/gold/aggregated_data_20240827.parquet
# 2024-08-27 20:43:49.094 | INFO     | __main__:load_predictions:93 - Loading predictions from data/energy_consumption/predictions/predictions_20240827.parquet

# %% [markdown]
# # Quality Checks

# %%
quality_report = {data_name: discover_df(data) for data_name, data in data_dict.items()}

# %% [markdown]
# ## Bronze

# %%
display(data_dict['bronze'].head())
quality_report['bronze'].to_dict()
# Out:
#   cod_areacarga           din_atualizacao dat_referencia  \
# 0            SP  2023-04-28T04:58:15.065Z     2021-03-01
# 1            SP  2023-04-28T04:58:15.065Z     2021-03-01
# 2            SP  2023-04-28T04:58:15.065Z     2021-03-01
# 3            SP  2023-04-28T04:58:15.065Z     2021-03-01
# 4            SP  2023-04-28T04:58:15.065Z     2021-03-01
#
#           din_referenciautc  val_cargaglobal  val_cargaglobalcons  \
# 0  2021-03-01T03:30:00.000Z        14785.096            14785.096
# 1  2021-03-01T04:00:00.000Z        14307.296            14307.296
# 2  2021-03-01T04:30:00.000Z        13920.842            13920.842
# 3  2021-03-01T05:00:00.000Z        13615.293            13615.293
# 4  2021-03-01T05:30:00.000Z        13452.070            13452.070
#
#    val_cargaglobalsmmgd  val_cargasupervisionada  val_carganaosupervisionada  \
# 0             14780.366               14463.5740                    316.7916
# 1             14302.565               13985.7480                    316.8175
# 2             13916.111               13599.2500                    316.8610
# 3             13610.563               13293.5690                    316.9945
# 4             13447.342               13130.2705                    317.0712
#
#    val_cargammgd  val_consistencia
# 0         4.7297               0.0
# 1         4.7303               0.0
# 2         4.7304               0.0
# 3         4.7296               0.0
# 4         4.7285               0.0
# OrderedDict([('creation_metadata',
#               OrderedDict([('local_time', '2024-08-27T20:43:49'),
#                            ('utc_time', '2024-08-27T23:43:49'),
#                            ('creator', 'TDDA 2.2.05'),
#                            ('host', 'pedro-A70-MOB'),
#                            ('user', 'pedro'),
#                            ('n_records', 61152),
#                            ('n_selected', 61152)])),
#              ('fields',
#               OrderedDict([('cod_areacarga',
#                             OrderedDict([('type', 'string'),
#                                          ('min_length', 2),
#                                          ('max_length', 2),
#                                          ('max_nulls', 0),
#                                          ('allowed_values', ['SP'])])),
#                            ('din_atualizacao',
#                             OrderedDict([('type', 'string'),
#                                          ('min_length', 24),
#                                          ('max_length', 24),
#                                          ('max_nulls', 0)])),
#                            ('dat_referencia',
#                             OrderedDict([('type', 'string'),
#                                          ('min_length', 10),
#                                          ('max_length', 10),
#                                          ('max_nulls', 0)])),
#                            ('din_referenciautc',
#                             OrderedDict([('type', 'string'),
#                                          ('min_length', 24),
#                                          ('max_length', 24),
#                                          ('max_nulls', 0),
#                                          ('no_duplicates', True)])),
#                            ('val_cargaglobal',
#                             OrderedDict([('type', 'real'),
#                                          ('min', -8456.68),
#                                          ('max', 26495.3),
#                                          ('max_nulls', 0)])),
#                            ('val_cargaglobalcons',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 9837.16),
#                                          ('max', 26495.3),
#                                          ('sign', 'positive'),
#                                          ('max_nulls', 0)])),
#                            ('val_cargaglobalsmmgd',
#                             OrderedDict([('type', 'real'),
#                                          ('min', -10784.425),
#                                          ('max', 24845.97),
#                                          ('max_nulls', 0)])),
#                            ('val_cargasupervisionada',
#                             OrderedDict([('type', 'real'),
#                                          ('min', -11032.808),
#                                          ('max', 24505.846),
#                                          ('max_nulls', 0)])),
#                            ('val_carganaosupervisionada',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 137.9281),
#                                          ('max', 2182.0903),
#                                          ('sign', 'positive'),
#                                          ('max_nulls', 0)])),
#                            ('val_cargammgd',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 0.0),
#                                          ('max', 2954.6985),
#                                          ('sign', 'non-negative'),
#                                          ('max_nulls', 0)])),
#                            ('val_consistencia',
#                             OrderedDict([('type', 'real'),
#                                          ('min', -2151.1973),
#                                          ('max', 31053.244),
#                                          ('max_nulls', 0)]))]))])

# %% [markdown]
# ## Silver

# %%
display(data_dict['silver'].head())
quality_report['silver'].to_dict()
# Out:
#                  data   carga_mw
# 0 2021-03-01 03:30:00  14785.096
# 1 2021-03-01 04:00:00  14307.296
# 2 2021-03-01 04:30:00  13920.842
# 3 2021-03-01 05:00:00  13615.293
# 4 2021-03-01 05:30:00  13452.070
# OrderedDict([('creation_metadata',
#               OrderedDict([('local_time', '2024-08-27T20:43:49'),
#                            ('utc_time', '2024-08-27T23:43:49'),
#                            ('creator', 'TDDA 2.2.05'),
#                            ('host', 'pedro-A70-MOB'),
#                            ('user', 'pedro'),
#                            ('n_records', 61152),
#                            ('n_selected', 61152)])),
#              ('fields',
#               OrderedDict([('data',
#                             OrderedDict([('type', 'date'),
#                                          ('min', '2021-03-01 03:30:00'),
#                                          ('max', '2024-08-26 03:00:00'),
#                                          ('max_nulls', 0)])),
#                            ('carga_mw',
#                             OrderedDict([('type', 'real'),
#                                          ('min', -8456.68),
#                                          ('max', 26495.3),
#                                          ('max_nulls', 0)]))]))])

# %% [markdown]
# ## Gold

# %%
display(data_dict['gold'].head())
quality_report['gold'].to_dict()
# Out:
#         date  daily_carga_mw
# 0 2021-03-01     740064.1270
# 1 2021-03-02     910450.2090
# 2 2021-03-03     909328.9410
# 3 2021-03-04     904879.8490
# 4 2021-03-05     878506.3495
# OrderedDict([('creation_metadata',
#               OrderedDict([('local_time', '2024-08-27T20:43:49'),
#                            ('utc_time', '2024-08-27T23:43:49'),
#                            ('creator', 'TDDA 2.2.05'),
#                            ('host', 'pedro-A70-MOB'),
#                            ('user', 'pedro'),
#                            ('n_records', 1275),
#                            ('n_selected', 1275)])),
#              ('fields',
#               OrderedDict([('date',
#                             OrderedDict([('type', 'date'),
#                                          ('min', '2021-03-01 00:00:00'),
#                                          ('max', '2024-08-26 00:00:00'),
#                                          ('max_nulls', 0)])),
#                            ('daily_carga_mw',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 112149.84199999999),
#                                          ('max', 1086165.883),
#                                          ('sign', 'positive'),
#                                          ('max_nulls', 0)]))]))])

# %% [markdown]
# ## Predictions

# %%
display(data_dict['predictions'].head())
quality_report['predictions'].to_dict()
# Out:
#           ds           y  unique_id  CatBoostRegressor  LGBMRegressor  \
# 0 2024-06-15  816371.131          0                NaN            NaN
# 1 2024-06-16  727934.964          0                NaN            NaN
# 2 2024-06-17  851129.980          0                NaN            NaN
# 3 2024-06-18  886222.722          0                NaN            NaN
# 4 2024-06-19  890934.761          0                NaN            NaN
#
#    XGBRegressor  RandomForestRegressor  CatBoostRegressor-lo-99  \
# 0           NaN                    NaN                      NaN
# 1           NaN                    NaN                      NaN
# 2           NaN                    NaN                      NaN
# 3           NaN                    NaN                      NaN
# 4           NaN                    NaN                      NaN
#
#    CatBoostRegressor-lo-95  CatBoostRegressor-lo-90  ...  \
# 0                      NaN                      NaN  ...
# 1                      NaN                      NaN  ...
# 2                      NaN                      NaN  ...
# 3                      NaN                      NaN  ...
# 4                      NaN                      NaN  ...
#
#    RandomForestRegressor-hi-20  RandomForestRegressor-hi-30  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    RandomForestRegressor-hi-40  RandomForestRegressor-hi-50  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    RandomForestRegressor-hi-60  RandomForestRegressor-hi-70  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    RandomForestRegressor-hi-80  RandomForestRegressor-hi-90  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    RandomForestRegressor-hi-95  RandomForestRegressor-hi-99
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
# [5 rows x 95 columns]
# OrderedDict([('creation_metadata',
#               OrderedDict([('local_time', '2024-08-27T20:43:49'),
#                            ('utc_time', '2024-08-27T23:43:49'),
#                            ('creator', 'TDDA 2.2.05'),
#                            ('host', 'pedro-A70-MOB'),
#                            ('user', 'pedro'),
#                            ('n_records', 133),
#                            ('n_selected', 133)])),
#              ('fields',
#               OrderedDict([('ds',
#                             OrderedDict([('type', 'date'),
#                                          ('min', '2024-06-15 00:00:00'),
#                                          ('max', '2024-10-25 00:00:00'),
#                                          ('max_nulls', 0)])),
#                            ('y',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 698073.5960000001),
#                                          ('max', 934259.6354999999),
#                                          ('sign', 'positive')])),
#                            ('unique_id',
#                             OrderedDict([('type', 'int'),
#                                          ('min', 0),
#                                          ('max', 0),
#                                          ('sign', 'zero'),
#                                          ('max_nulls', 0)])),
#                            ('CatBoostRegressor',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 671796.9061474057),
#                                          ('max', 909316.514871865),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 650949.1518362488),
#                                          ('max', 891934.3453609645),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 667445.625),
#                                          ('max', 905230.375),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 678913.3229599999),
#                                          ('max', 879332.6626150003),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 618474.3923557196),
#                                          ('max', 868138.9303315585),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 622557.8311662587),
#                                          ('max', 869577.6387029456),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 627662.1296794324),
#                                          ('max', 871376.0241671796),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 637870.72670578),
#                                          ('max', 874972.7950956475),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 648079.3237321276),
#                                          ('max', 878569.5660241154),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 658022.3242530219),
#                                          ('max', 882166.3369525834),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 658917.6857483669),
#                                          ('max', 887244.4049013228),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 659547.4507382588),
#                                          ('max', 892322.4728500622),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 660177.2157281507),
#                                          ('max', 897400.5407988017),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 660806.9807180425),
#                                          ('max', 902478.6087475411),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-lo-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 666301.9434327241),
#                                          ('max', 905897.561809703),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 677291.8688620874),
#                                          ('max', 912735.4679340271),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 682786.831576769),
#                                          ('max', 916154.420996189),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 683416.5965666608),
#                                          ('max', 921232.4889449284),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 684046.3615565527),
#                                          ('max', 926310.5568936679),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 684676.1265464446),
#                                          ('max', 931388.6248424073),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 685305.8915363364),
#                                          ('max', 936466.6927911467),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 695514.4885626839),
#                                          ('max', 940063.4637196147),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 705723.0855890315),
#                                          ('max', 943660.2346480826),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 715931.6826153791),
#                                          ('max', 947257.0055765505),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 721035.9811285528),
#                                          ('max', 949055.3910407845),
#                                          ('sign', 'positive')])),
#                            ('CatBoostRegressor-hi-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 725119.4199390919),
#                                          ('max', 950494.0994121716),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 630566.7559696762),
#                                          ('max', 867347.8884514864),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 632340.7395925424),
#                                          ('max', 869121.8720743526),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 634558.2191211253),
#                                          ('max', 871339.3516029355),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 638993.1781782908),
#                                          ('max', 875774.310660101),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 643428.1372354564),
#                                          ('max', 880209.2697172666),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 647863.096292622),
#                                          ('max', 884644.2287744322),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 648007.0134784157),
#                                          ('max', 884788.1459602258),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 648150.9306642094),
#                                          ('max', 884932.0631460196),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 648294.847850003),
#                                          ('max', 885075.9803318132),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 648438.7650357967),
#                                          ('max', 887744.9090243423),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-lo-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 649693.9584360227),
#                                          ('max', 889839.6271926535),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 652204.3452364749),
#                                          ('max', 894029.0635292756),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 653459.538636701),
#                                          ('max', 896123.7816975868),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 653603.4558224946),
#                                          ('max', 901058.5179163974),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 653747.3730082882),
#                                          ('max', 905993.2541352082),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 653891.290194082),
#                                          ('max', 910927.9903540189),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 654035.2073798756),
#                                          ('max', 915862.7265728295),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 658470.1664370412),
#                                          ('max', 920069.3232928223),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 662905.1254942068),
#                                          ('max', 924275.9200128152),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 667340.0845513723),
#                                          ('max', 928482.5167328079),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 669557.5640799552),
#                                          ('max', 930585.8150928043),
#                                          ('sign', 'positive')])),
#                            ('LGBMRegressor-hi-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 671331.5477028214),
#                                          ('max', 932268.4537808014),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 638197.5236125),
#                                          ('max', 866213.8361125),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 639488.1820625),
#                                          ('max', 867504.4945625),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 641101.5051250001),
#                                          ('max', 869117.8176250001),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 644328.1512500001),
#                                          ('max', 877449.876),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 647554.7973750001),
#                                          ('max', 887732.4975),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 650781.4435000002),
#                                          ('max', 898015.119),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 650930.7830000002),
#                                          ('max', 899305.893375),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 651080.1225000002),
#                                          ('max', 900596.6677499999),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 651229.4620000002),
#                                          ('max', 901887.4421249998),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 651378.8015000002),
#                                          ('max', 903178.2164999999),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-lo-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 659412.21325),
#                                          ('max', 904204.2957499999),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 675479.03675),
#                                          ('max', 906256.4542500001),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 683512.4484999998),
#                                          ('max', 911528.7609999998),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 683661.7879999998),
#                                          ('max', 911678.1004999998),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 683811.1274999998),
#                                          ('max', 911827.4399999998),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 683960.4669999998),
#                                          ('max', 911976.7794999998),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 684109.8064999998),
#                                          ('max', 912445.631),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 687336.4526249999),
#                                          ('max', 922728.2525),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 690563.0987499999),
#                                          ('max', 933010.874),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 693789.7448749999),
#                                          ('max', 943293.4955),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 695403.0679375),
#                                          ('max', 948434.8062499999),
#                                          ('sign', 'positive')])),
#                            ('XGBRegressor-hi-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 696693.7263875),
#                                          ('max', 952547.8548499999),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 650379.4162324994),
#                                          ('max', 839852.7367850002),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 652477.3814650002),
#                                          ('max', 841697.1035850001),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 654782.839965),
#                                          ('max', 844002.562085),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 659393.756965),
#                                          ('max', 849200.213535),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 664004.6739649997),
#                                          ('max', 856187.54156),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 668615.5909649995),
#                                          ('max', 863174.869585),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 669434.0008812497),
#                                          ('max', 864949.9446187501),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 670252.4107974998),
#                                          ('max', 866725.0196525004),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 671070.8207137499),
#                                          ('max', 868500.0946862507),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 671889.23063),
#                                          ('max', 870275.1697200008),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-lo-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 675401.276795),
#                                          ('max', 874803.9161675005),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-10',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 682425.3691249999),
#                                          ('max', 883861.4090625),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-20',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 685937.4152899998),
#                                          ('max', 888390.1555099997),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-30',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 686755.82520625),
#                                          ('max', 890165.2305437499),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-40',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 687574.2351225),
#                                          ('max', 891940.3055775001),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-50',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 688392.6450387501),
#                                          ('max', 893715.3806112504),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-60',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 689211.0549550003),
#                                          ('max', 895490.4556450006),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-70',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 693821.9719550001),
#                                          ('max', 902477.7836700005),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-80',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 698432.8889549999),
#                                          ('max', 909465.1116950006),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-90',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 703043.8059549998),
#                                          ('max', 916452.4397200006),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-95',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 705349.2644549996),
#                                          ('max', 919946.1037325006),
#                                          ('sign', 'positive')])),
#                            ('RandomForestRegressor-hi-99',
#                             OrderedDict([('type', 'real'),
#                                          ('min', 707193.6312549995),
#                                          ('max', 922741.0349425005),
#                                          ('sign', 'positive')]))]))])

# %% [markdown]
# ## Save it

# %%
# # Save the quality report to a JSON file
# for data_name, report in quality_report.items():
#     with open(f"../src/data/quality_reports/{data_name}_quality_report.json", "w") as file:
#         file.write(report.to_json())
#         print(f"Quality report for {data_name} saved to ../data/quality_reports/{data_name}_quality_report.json")

# %% [markdown]
# # Infer schemas

# %%
from pandera.schema_inference.pandas import infer_schema

for data_name, data in data_dict.items():
    schema = infer_schema(data)
    #schema.to_script("../src/data/schemas/{}_schema.py".format(data_name))
    print(f"Schema for {data_name} saved to ../data/schemas/{data_name}_schema.py")
# Out:
# Schema for bronze saved to ../data/schemas/bronze_schema.py
# Schema for silver saved to ../data/schemas/silver_schema.py
# Schema for gold saved to ../data/schemas/gold_schema.py
# Schema for predictions saved to ../data/schemas/predictions_schema.py

# %% [markdown]
# # Check Schemas

# %%
from src.data.schemas.bronze_schema import schema as bronze_schema
from src.data.schemas.silver_schema import schema as silver_schema
from src.data.schemas.gold_schema import schema as gold_schema
from src.data.schemas.predictions_schema import schema as predictions_schema

# %%
bronze_schema.validate(data_dict['bronze'])
# Out:
#       cod_areacarga           din_atualizacao dat_referencia  \
# 0                SP  2023-04-28T04:58:15.065Z     2021-03-01
# 1                SP  2023-04-28T04:58:15.065Z     2021-03-01
# 2                SP  2023-04-28T04:58:15.065Z     2021-03-01
# 3                SP  2023-04-28T04:58:15.065Z     2021-03-01
# 4                SP  2023-04-28T04:58:15.065Z     2021-03-01
# ...             ...                       ...            ...
# 61147            SP  2024-08-27T03:22:24.348Z     2024-08-25
# 61148            SP  2024-08-27T03:22:24.348Z     2024-08-25
# 61149            SP  2024-08-27T03:22:24.348Z     2024-08-25
# 61150            SP  2024-08-27T03:22:24.348Z     2024-08-25
# 61151            SP  2024-08-27T03:22:24.348Z     2024-08-25
#
#               din_referenciautc  val_cargaglobal  val_cargaglobalcons  \
# 0      2021-03-01T03:30:00.000Z        14785.096            14785.096
# 1      2021-03-01T04:00:00.000Z        14307.296            14307.296
# 2      2021-03-01T04:30:00.000Z        13920.842            13920.842
# 3      2021-03-01T05:00:00.000Z        13615.293            13615.293
# 4      2021-03-01T05:30:00.000Z        13452.070            13452.070
# ...                         ...              ...                  ...
# 61147  2024-08-26T01:00:00.000Z        16666.055            16666.055
# 61148  2024-08-26T01:30:00.000Z        16123.604            16123.604
# 61149  2024-08-26T02:00:00.000Z        15480.127            15480.127
# 61150  2024-08-26T02:30:00.000Z        14918.517            14918.517
# 61151  2024-08-26T03:00:00.000Z        14395.287            14395.287
#
#        val_cargaglobalsmmgd  val_cargasupervisionada  \
# 0                 14780.366               14463.5740
# 1                 14302.565               13985.7480
# 2                 13916.111               13599.2500
# 3                 13610.563               13293.5690
# 4                 13447.342               13130.2705
# ...                     ...                      ...
# 61147             16649.766               15236.8670
# 61148             16107.161               14690.5790
# 61149             15463.709               14043.7480
# 61150             14902.227               13479.8300
# 61151             14378.997               12956.5020
#
#        val_carganaosupervisionada  val_cargammgd  val_consistencia
# 0                        316.7916         4.7297               0.0
# 1                        316.8175         4.7303               0.0
# 2                        316.8610         4.7304               0.0
# 3                        316.9945         4.7296               0.0
# 4                        317.0712         4.7285               0.0
# ...                           ...            ...               ...
# 61147                   1412.8990        16.2900               0.0
# 61148                   1416.5818        16.4421               0.0
# 61149                   1419.9609        16.4179               0.0
# 61150                   1422.3960        16.2900               0.0
# 61151                   1422.4954        16.2900               0.0
#
# [61152 rows x 11 columns]

# %%
silver_schema.validate(data_dict['silver'])
# Out:
#                      data   carga_mw
# 0     2021-03-01 03:30:00  14785.096
# 1     2021-03-01 04:00:00  14307.296
# 2     2021-03-01 04:30:00  13920.842
# 3     2021-03-01 05:00:00  13615.293
# 4     2021-03-01 05:30:00  13452.070
# ...                   ...        ...
# 61147 2024-08-26 01:00:00  16666.055
# 61148 2024-08-26 01:30:00  16123.604
# 61149 2024-08-26 02:00:00  15480.127
# 61150 2024-08-26 02:30:00  14918.517
# 61151 2024-08-26 03:00:00  14395.287
#
# [61152 rows x 2 columns]

# %%
gold_schema.validate(data_dict['gold'])
# Out:
#            date  daily_carga_mw
# 0    2021-03-01     740064.1270
# 1    2021-03-02     910450.2090
# 2    2021-03-03     909328.9410
# 3    2021-03-04     904879.8490
# 4    2021-03-05     878506.3495
# ...         ...             ...
# 1270 2024-08-22     929876.4890
# 1271 2024-08-23     934259.6355
# 1272 2024-08-24     855712.3575
# 1273 2024-08-25     748091.7795
# 1274 2024-08-26     112149.8420
#
# [1275 rows x 2 columns]

# %%
predictions_schema.validate(data_dict['predictions'])
# Out:
#             ds           y  unique_id  CatBoostRegressor  LGBMRegressor  \
# 0   2024-06-15  816371.131          0                NaN            NaN
# 1   2024-06-16  727934.964          0                NaN            NaN
# 2   2024-06-17  851129.980          0                NaN            NaN
# 3   2024-06-18  886222.722          0                NaN            NaN
# 4   2024-06-19  890934.761          0                NaN            NaN
# ..         ...         ...        ...                ...            ...
# 128 2024-10-21         NaN          0      803651.407382  769239.075103
# 129 2024-10-22         NaN          0      832695.684901  816920.088404
# 130 2024-10-23         NaN          0      823444.996255  826470.780959
# 131 2024-10-24         NaN          0      815474.443484  821612.337913
# 132 2024-10-25         NaN          0      817435.272256  811315.265071
#
#      XGBRegressor  RandomForestRegressor  CatBoostRegressor-lo-99  \
# 0             NaN                    NaN                      NaN
# 1             NaN                    NaN                      NaN
# 2             NaN                    NaN                      NaN
# 3             NaN                    NaN                      NaN
# 4             NaN                    NaN                      NaN
# ..            ...                    ...                      ...
# 128   816328.0625          798513.861240            762473.822842
# 129   880758.5000          839956.220215            791518.100361
# 130   893525.3750          843281.566845            782267.411714
# 131   891047.3125          831031.642050            774296.858944
# 132   852116.8125          821128.366280            776257.687715
#
#      CatBoostRegressor-lo-95  CatBoostRegressor-lo-90  ...  \
# 0                        NaN                      NaN  ...
# 1                        NaN                      NaN  ...
# 2                        NaN                      NaN  ...
# 3                        NaN                      NaN  ...
# 4                        NaN                      NaN  ...
# ..                       ...                      ...  ...
# 128            763912.531213            765710.916677  ...
# 129            792956.808732            794755.194196  ...
# 130            783706.120086            785504.505550  ...
# 131            775735.567315            777533.952779  ...
# 132            777696.396087            779494.781551  ...
#
#      RandomForestRegressor-hi-20  RandomForestRegressor-hi-30  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 128                805537.953570                806356.363486
# 129                846980.312545                847798.722461
# 130                850305.659175                851124.069091
# 131                838055.734380                838874.144296
# 132                828152.458610                828970.868526
#
#      RandomForestRegressor-hi-40  RandomForestRegressor-hi-50  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 128                807174.773403                807993.183319
# 129                848617.132378                849435.542294
# 130                851942.479008                852760.888924
# 131                839692.554213                840510.964129
# 132                829789.278443                830607.688359
#
#      RandomForestRegressor-hi-60  RandomForestRegressor-hi-70  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 128                808811.593235                813422.510235
# 129                850253.952210                854864.869210
# 130                853579.298840                858190.215840
# 131                841329.374045                845940.291045
# 132                831426.098275                836037.015275
#
#      RandomForestRegressor-hi-80  RandomForestRegressor-hi-90  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 128                818033.427235                822644.344235
# 129                859475.786210                864086.703210
# 130                862801.132840                867412.049840
# 131                850551.208045                855162.125045
# 132                840647.932275                845258.849275
#
#      RandomForestRegressor-hi-95  RandomForestRegressor-hi-99
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 128                824949.802735                826794.169535
# 129                866392.161710                868236.528510
# 130                869717.508340                871561.875140
# 131                857467.583545                859311.950345
# 132                847564.307775                849408.674575
#
# [133 rows x 95 columns]

# %%
bronze['din_atualizacao'] = pd.to_datetime(bronze['din_atualizacao']).apply(lambda x: x.replace(tzinfo=None))
bronze['din_referenciautc'] = pd.to_datetime(bronze['din_referenciautc']).apply(lambda x: x.replace(tzinfo=None))
bronze[['din_atualizacao','din_referenciautc','val_cargaglobal']].tail(30)
# Out:
#               din_atualizacao   din_referenciautc  val_cargaglobal
# 61122 2024-08-27 03:22:24.348 2024-08-25 12:30:00        14963.540
# 61123 2024-08-27 03:22:24.348 2024-08-25 13:00:00        15248.594
# 61124 2024-08-27 03:22:24.348 2024-08-25 13:30:00        15605.788
# 61125 2024-08-27 03:22:24.348 2024-08-25 14:00:00        15975.923
# 61126 2024-08-27 03:22:24.348 2024-08-25 14:30:00        16288.750
# 61127 2024-08-27 03:22:24.348 2024-08-25 15:00:00        16569.576
# 61128 2024-08-27 03:22:24.348 2024-08-25 15:30:00        16739.709
# 61129 2024-08-27 03:22:24.348 2024-08-25 16:00:00        16605.780
# 61130 2024-08-27 03:22:24.348 2024-08-25 16:30:00        16410.697
# 61131 2024-08-27 03:22:24.348 2024-08-25 17:00:00        16252.445
# 61132 2024-08-27 03:22:24.348 2024-08-25 17:30:00        16083.055
# 61133 2024-08-27 03:22:24.348 2024-08-25 18:00:00        15990.290
# 61134 2024-08-27 03:22:24.348 2024-08-25 18:30:00        15874.498
# 61135 2024-08-27 03:22:24.348 2024-08-25 19:00:00        16006.574
# 61136 2024-08-27 03:22:24.348 2024-08-25 19:30:00        16296.278
# 61137 2024-08-27 03:22:24.348 2024-08-25 20:00:00        16613.602
# 61138 2024-08-27 03:22:24.348 2024-08-25 20:30:00        17116.662
# 61139 2024-08-27 03:22:24.348 2024-08-25 21:00:00        17480.162
# 61140 2024-08-27 03:22:24.348 2024-08-25 21:30:00        18310.469
# 61141 2024-08-27 03:22:24.348 2024-08-25 22:00:00        18433.166
# 61142 2024-08-27 03:22:24.348 2024-08-25 22:30:00        18171.465
# 61143 2024-08-27 03:22:24.348 2024-08-25 23:00:00        18036.193
# 61144 2024-08-27 03:22:24.348 2024-08-25 23:30:00        17577.627
# 61145 2024-08-27 03:22:24.348 2024-08-26 00:00:00        17375.455
# 61146 2024-08-27 03:22:24.348 2024-08-26 00:30:00        17190.797
# 61147 2024-08-27 03:22:24.348 2024-08-26 01:00:00        16666.055
# 61148 2024-08-27 03:22:24.348 2024-08-26 01:30:00        16123.604
# 61149 2024-08-27 03:22:24.348 2024-08-26 02:00:00        15480.127
# 61150 2024-08-27 03:22:24.348 2024-08-26 02:30:00        14918.517
# 61151 2024-08-27 03:22:24.348 2024-08-26 03:00:00        14395.287
